# %%
# SPDX-License-Identifier: Apache-2.0 AND CC-BY-NC-4.0
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# http://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Notebook Title — Module Name: Subtitle
# $\renewcommand{\ket}[1]{|#1\rangle}\renewcommand{\bra}[1]{\langle#1|}$
#
# ---
#
# **What You Will Do:**
# * Apply `someFunction` to solve a specific problem
# * Implement an algorithm that achieves a measurable outcome
# * Compare Method A against Method B on a benchmark task
# * Visualize the behavior of a quantum system under varying parameters
#
# **Prerequisites:**
# * Python and Jupyter notebook familiarity
# * Basic knowledge of quantum computing (qubits, gates, measurement)
# * [Add module-specific prerequisites here, e.g., "Variational algorithms (Lab 03)"]
#
# **Key Terminology:**
# * Term One
# * Term Two (Full Name Expansion)
# * Term Three
#
# **CUDA-Q Syntax:**
# * [`@cudaq.kernel`](https://nvidia.github.io/cuda-quantum/latest/api/languages/python_api.html#cudaq.kernel) — defines a quantum kernel function
# * [`cudaq.sample`](https://nvidia.github.io/cuda-quantum/latest/api/languages/python_api.html#cudaq.sample) — samples measurement outcomes from a kernel
# * [`cudaq.observe`](https://nvidia.github.io/cuda-quantum/latest/api/languages/python_api.html#cudaq.observe) — computes the expectation value of a spin operator
#
# **Solutions:** [`solutions/notebook_template_solutions.ipynb`](solutions/notebook_template_solutions.ipynb)

# %% [markdown]
# <div style="background-color: #f9fff0; border-left: 6px solid #76b900; padding: 12px 15px 12px 20px; border-radius: 4px; margin: 15px 0; color: #333;">
#
# **<span style="color: #76b900;">&#9889; GPU Required:</span>** This notebook requires a GPU.
#
# </div>

# %%
## Instructions for Google Colab. You can ignore this cell if you have CUDA-Q
## set up locally with all required files on your system.
## Uncomment the lines below and execute this cell to install CUDA-Q.

#!pip install cudaq -q
#
#!wget -q https://github.com/nvidia/cuda-q-academic/archive/refs/heads/main.zip
#!unzip -q main.zip
#!mv cuda-q-academic-main/<module-folder>/Images ./Images

# %% [markdown]
# > **Note:** Run the cell below to import all required packages.
# > If you installed packages above, restart the kernel first
# > (**Runtime → Restart session** in Colab, or **Kernel → Restart** in Jupyter).

# %%
# Standard library
import os

# Scientific computing
import numpy as np

# Visualization
import matplotlib.pyplot as plt

# CUDA-Q
import cudaq
from cudaq import spin

# %% [markdown]
# ---
# ## 1. Introduction
#
# Introduce the topic in detail. Provide background information and context. Define key concepts — **bold** the first use of every term listed in **Key Terminology** above (e.g., "The **term one** is...").
#
# Use the ket macro for quantum state notation: $\ket{\psi}$, $\ket{0}$, $\ket{1}$.

# %% [markdown]
# ---
# ## 2. Main Content
#
# Distribute the core content across numbered sections (`## 1.`, `## 2.`, etc.) with a `---` rule before each.

# %% [markdown]
# <div style="background-color: #f9fff0; border-left: 6px solid #76b900; padding: 15px 15px 15px 20px; border-radius: 4px; margin: 15px 0; color: #333;">
#
# **<span style="color: #76b900; font-size: 1.17em;">Exercise 1:</span>**
#
# Write a function that takes two numbers and returns their sum.
#
# </div>

# %%
# EXERCISE 1

def add_numbers(a: int, b: int) -> int:
    """
    Add two numbers and return the result.

    Parameters:
    -----------
    a : int
        First number.
    b : int
        Second number.

    Returns:
    --------
    int
        The sum of a and b.
    """
    ##TODO## implement this function
    pass

# Example usage
print(add_numbers(2, 3))  # Expected output: 5

# %% [markdown]
# ## Conclusion
#
# Summarize the key takeaways from this notebook:
# * What core concepts did the learner encounter?
# * What did the exercises demonstrate?
# * What are the limitations of the approaches shown?
#
# **Next steps:** Point learners to the next notebook in the learning path or to related topics.

# %% [markdown]
# **Related Notebooks:**
# * [Notebook Title](https://github.com/NVIDIA/cuda-q-academic/blob/main/module/notebook.ipynb) — brief reason for relevance
# * [Notebook Title](https://github.com/NVIDIA/cuda-q-academic/blob/main/module/notebook.ipynb) — brief reason for relevance
# * [Notebook Title](https://github.com/NVIDIA/cuda-q-academic/blob/main/module/notebook.ipynb) — brief reason for relevance
